# %% [markdown]
# <a href="https://colab.research.google.com/github/RuslanFF1968/Data-Science-For-Beginners/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://omniweb.gsfc.nasa.gov/coho/helios/heli.html'

# %%
response = requests.get(url)
print(response)
bs = BeautifulSoup(response.text,"lxml")
print(bs)
# Out:
# <Response [200]>
# <html> <head>
# <title> Heliocentric  Trajectories for Selected Spacecraft,Planets, and Comets</title>
# <script id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=GSFC" type="text/javascript"></script>
# </head>
# <body bgcolor="#F1F1F1">
# <p align="left"><a href="/coho/helios/heli.html"><img alt="HelioWeb" border="0" src="helioweb.jpg"/></a>
# </p><hr align="" size="1"/>
# <font color="blue" size="4"><b> Heliocentric  Trajectories for Selected Spacecraft, Planets, and Comets</b></font>
# <hr width="75%"/>
# The original trajectory data are taken from
# <!-- <a href="http://ssd.jpl.nasa.gov/horizons.cgi"> <b>http://ssd.jpl.nasa.gov/horizons.cgi </b></a> -->
# <a href="https://ssd.jpl.nasa.gov/horizons/app.html#/"> <b>https://ssd.jpl.nasa.gov/horizons/app.html#/ </b></a>
#
# where users can find many more objects.
# <p>
# <b>
# ...
